# %% [markdown]
# # Exercise 1
#
# 1. Download the `british-english` file from absalon or Github.
# 2. Read it into a `DataFrame` . Are there any options you need to add to make it work? **Hint 1: Print the dataframe and see if you can find an issue. Hint 2: Check the Header parameter in the [documentation](https://pandas.pydata.org/docs/reference/api/pandas.read_table.html). Hint 3: Continue to 3. and see if it helps you spot the issue.**
# 3. Figure out how to assign a different column name - e.g. 'words' **Hint: Start by figuring out how to print the column name, then assign a new name.**
# 4. Figure out how to select all rows starting with the letter A. **Hint 1: Use the string accessor on a column. Hint 2: See the str startswith method in the [documentation](https://docs.python.org/3/library/stdtypes.html#string-methods).**

# %%
# Your code here

# %% [markdown]
# # Exercise 2
#
# 1. Download `british-english_a-e` and `american-english_a-e` file from Github or absalon.
# 2. Read them into two `DataFrame` variables `df1` and `df2`. Set the column name to `words` for both dataframes.
# 3. Merge the two word lists to a dataframe `df`. **Hint: check the argument `how` in pd.merge() (look in the documentation or search the web).**

# %%
# Your code here

# %% [markdown]
# ## Exercise 3 - Soccer
# The data is a list of lists of association football clubs (highest level in each country) from all over the world in June 2022. Your task is to process the dataset and create meaningful visualizations using Pandas and Matplotlib.

# %% [markdown]
# ### Data
# The file `soccer_clubs_ranking.csv` contains information about soccer clubs in the following columns:
# - `ranking`: current rank of the club
# - `club name`: club name
# - `country`: country that the club comes from
# - `point score`: current score in June 2022
# - `1 year change`: the score change in the past year
# - `symbol change`: symbol of score change in the past year (+ or -)

# %% [markdown]
# ### Requirements
# 1. Data Loading and Preprocessing:
#     - Read the CSV file using pandas and store it in variable df
#     - Set the index to be the rank of each club (hint: you may directly assign the `ranking` values to `df.index`)
#     - Rank the clubs by index using `df.sort_index()`
#     - Make sure the value of df is updated by the operations (hint: you could check the first 5 rows by using
#     - `df.head(5)` before and after your processing)
#
# 2. Data Analysis:
#     - Create a dictionary called `club_count_dict` that shows:
#         - Keys: countries
#         - Values: count of clubs in each contry
#     - Use `df.groupby()` and `count()` operations to get a pd.dataframe for the counts as `club_count_df`
#     - Convert it to dictionary using `club_count_df.to_dict()` and assign it to `club_count_dict`
#
# 3. Data Visualization: Create a figure with two subplots:
#     - First subplot: Bar plot showing the point scores of top 10 clubs in the world:
#         - x labels being country names, bar values (y labels) being average point scores Please plot the data for any 10 countries you like
#         - Hint: Use `df.groupby()` and `mean()` operations; `df.plot.bar()``
#     - Display all plots using `plt.show()`

# %% [markdown]
# ### Expected structure
#
# ```python
# # Data Loading and Preprocessing
# df = pd.read_csv('soccer_clubs_ranking.csv')
# # ... preprocessing steps ...
# ​
# # Data Analysis
# club_count_dict = # ... groupby operations ...
# ​
# # Visualization
# fig, axes = plt.subplots(1, 2)
# # ... create two subplots ...
# plt.show()
# ```

# %%
# Your code here

# %% [markdown]
# ## Exercise 3 - Visualize protein structure
# You will analyze and visualize protein structure data using Pandas and Matplotlib. Your task is to process a dataset containing protein structure information and create meaningful visualizations to understand the data distribution.
#
# ### The Data
# The file ’structural_protein_sequence.csv’ contains information about protein structures with the following columns:
# - `structureId`: Unique identifier for the structure
# - `classification`: Type of protein structure
# - `experimentalTechnique`: Method used to determine structure
# - `macromoleculeType`: Type of macromolecule
# - `residueCount`: Number of residues in structure
# - `resolution`: Resolution of structure
# - `structureMolecularWeight`: Molecular weight
# - `publicationYear`: Year of publication
#
# ### Requirements:
#
# #### 1. Data Loading and Preprocessing:
# - Read the CSV file using pandas and store it in variable `df`
# - Select only the first 100 rows
# - Keep only these columns: `tructureID`, `classification`,
# `experimentalTechnique`, `macromoleculeType`, `residueCount`,
# `resolution`,`structureMolecularWeight`,`publicationYear`
# - Convert `publicationYear` to integer type
# - Remove rows with missing values
# - Reset the index
#
# #### 2. Data analysis
# - Create a dictionary called `sample_year_dict` that shows:
#     - Keys: publication years
#     - Values: count of structures published in each year
# - Use Pandas built-in `groupby()` and `count()` operations for the
# dataframe df
#
# #### 3. Data Visualization:
# - First subplot: Bar plot showing the count of structures by
# `macromoleculeType`
# - Second subplot: Histogram of `residueCount` with 10 bins
# - Third subplot: Box plot of `structureMolecularWeight` grouped by
# `publicationYear`
# - Remove the overall figure title using `fig.suptitle('')`
# - Display all plots using plt.show()

# %%
# Your code here
