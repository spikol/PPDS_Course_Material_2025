# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 1) Load in the data `ILI_trends.csv` in a dataframe and call the dataframe `df`
# 2) print the first five rows of `df`

# %%
# TODO# TODO
#TODO
# Out:
# Raw data (first 5 rows):
#       date      ILI  antigenic_drift  antigenic_shift  body_aches  \
# 0   1/4/04  2.41833              0.0              0.0         0.0
# 1  1/11/04  1.80906              0.0              0.0         0.0
# 2  1/18/04  1.71202              0.0              0.0         0.0
# 3  1/25/04  1.54250              0.0              0.0         0.0
# 4   2/1/04  1.43787              0.0              0.0         0.0
#
#    caught_the_flu  child_fever_flu  chills      cough   diarrhea  ...  \
# 0             0.0              0.0    0.70  19.310961  11.883668  ...
# 1             0.0              0.0    1.00  17.825503   8.912751  ...
# 2             0.0              0.0    1.68  14.854585  10.398210  ...
# 3             0.0              0.0    1.18  14.854585  10.398210  ...
# 4             0.0              0.0    1.06  14.854585   8.912751  ...
#
#    severe_flu  shortness_of_breath  sneezing  sore_throat  stomach_flu  \
# ...

# %% [markdown]
# 1) Use `pd.to_datetime` to convert the 'date' column to a proper datetime type using the argument `format="%m/%d/%y"` to specify the date time format. Then sort the rows by date, and set 'date' as the DataFrame index.
# 2) Ther is a column named "ILI", print the mean, median, minimum, and maximum of that column. The result should look like the following:
# ```
# 2.009739664246824
# 1.53103
# 0.534093
# 7.79783
# ```

# %%
#TODO
# Out:
# 2.009739664246824
# 1.53103
# 0.534093
# 7.79783

# %% [markdown]
# 1) Generate a simple plot that shows `["ILI"]` as a times series variable, using a simple lineplot. Set the title to `"Influenza-like illness (ILI) over time"`, X label to `"Date"` and Y label to `"ILI"`. Simply use the index as the y axis

# %%
#TODO

# %% [markdown]
# 1) Create a new dataframe called `google_search_df` that contains only the following columns `"flu", "fever", "cough"` from your original `df`
# 2) Now simply plot use the inbedded function `.plot()` from pandas and plot `google_search_df`. Set the title to `"Selected Google search queries over time"` the xlabel to `"Date"` and ylabel to `"Search frequency (index)"`

# %%
#TODO

# %% [markdown]
# 1) Figure out what the numerical columns of `df` are and use the pandas function `.corr` to compute the Pearson correlation between ILI and each numeric column.
# 2) Print the top 15 columns that are most positively correlated with ILI.
# 3) Specifically print correlations for 'flu', 'fever', and 'cough'.
#
# If, in doubt, look up documentation on `.corr` at: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.corr.html

# %%
#TODO
# Out:
# Top 15 same-week correlations with ILI:
# ILI                      1.000000
# influenza_symptoms       0.820772
# flu_medicine             0.816851
# influenza_a              0.759711
# cough                    0.720007
# influenza_b              0.716938
# severe_flu               0.707862
# vomiting_flu             0.683911
# child_fever_flu          0.678892
# oseltamivir              0.653615
# flu_now                  0.642612
# early_flu_symptoms       0.623080
# nasal_congestion         0.601584
# fever                    0.594653
# flu_incubation_period    0.585013
# Name: ILI, dtype: float64
# Correlation between ILI and 'flu': 0.475
# Correlation between ILI and 'fever': 0.595
# Correlation between ILI and 'cough': 0.720

# %% [markdown]
# 1) Using your `df`, create a **numpy** array called `y_true`  from the "ILI" column of your `df`:
# 2) Now create a simple “prediction” array called `y_pred_const` that predicts the mean of `y_true` for every index

# %%
# TODO
# TODO# TODO

# %% [markdown]
# 1) Now we want to evaluate the error of our predictions using various measures
# $$
# \operatorname{MSE} = \frac{1}{n} \sum_{i=1}^{n} \left (y_i - \hat{y_i} \right)^{2}
# $$
# $$
# \operatorname{RMSE} = \frac{1}{n} \sum_{i=1}^{n} \sqrt{\left  (y_i - \hat{y_i} \right)^{2} }
# $$
# $$
# \operatorname{MAE} = \frac{1}{n} \sum_{i=1}^{n} \left | y_i - \hat{y_i} \right |
# $$
#
# call the three functions `def mse(y_true, y_pred):`, `def rmse(y_true, y_pred):` and `def mae(y_true, y_pred):`.
# Now evaluate your `y_pred_const` as the predictions against the target `y_true` using your three functions and print the MSE, RMSE and MAE of your mean predictions

# %%
#TODO
# Out:
# Constant predictor:
#   MSE : 1.8949955782700667
#   RMSE: 1.3765883837480493
#   MAE : 1.0036177445561774

# %% [markdown]
# Now you are given the following weight vector and bias of a trained linear model:
#
# `W = np.array([0.05365188, 0.01521512, 0.01144632])`
# `b = -0.8502437631312914`
#
# We will use the feature matrix
#
# $$
# X =
# \begin{pmatrix}
# x_{0,0} & x_{0,1} & x_{0,2} \\
# x_{1,0} & x_{1,1} & x_{1,2} \\
# \vdots  & \vdots  & \vdots  \\
# x_{n,0} & x_{n,1} & x_{n,2}
# \end{pmatrix},
# $$
#
# where each row corresponds to one person, and the columns are:
#
# - $x_{i,0}$: cough for person $i$
# - $x_{i,1}$: fever for person $i$
# - $x_{i,2}$: flu for person $i$
#
# The weight vector and bias are
#
# $$
# w =
# \begin{pmatrix}
# 0.05365188 \\
# 0.01521512 \\
# 0.01144632
# \end{pmatrix},
# \qquad
# b = -0.8502437631312914.
# $$
#
# Your task is to compute the prediction vector $\hat{y}$ using **one** matrix–vector multiplication and a bias term:
#
# $$
# \hat{y} = X w + b.
# $$
#
# Component-wise, for each person $i = 0, 1, \dots, n$,
#
# $$
# \hat{y}_i
# = 0.05365188 \cdot x_{i,0}
# + 0.01521512 \cdot x_{i,1}
# + 0.01144632 \cdot x_{i,2}
# - 0.8502437631312914.
# $$
#
# In NumPy, this corresponds to (The answer)
#
# ```python
# ....

# %%
#TODO

# %% [markdown]
# Now use your functions `mse`, `rmse`, `mae` to ocmpute the errors of your new predictions

# %%
#TODO
# Out:
#   MSE : 0.8468844642103285
#   RMSE: 0.9202632581008157
#   MAE : 0.5709635332794752

# %% [markdown]
# Finally, plot `y_true` alongside `y_pred_const` and `y_pred`

# %%
#TODO
